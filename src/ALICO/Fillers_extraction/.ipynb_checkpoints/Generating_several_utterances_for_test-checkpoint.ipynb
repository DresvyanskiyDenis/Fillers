# %%
import numpy as np
from scipy.io import wavfile
from main import extract_label_timesteps_from_files_in_dir, extract_label_timesteps_from_file, extract_utterance_according_timesteps

# %%
label_timesteps=extract_label_timesteps_from_files_in_dir(r'E:\Databases\ALICO\ALICO\alico_coop\segmentation',
                                                          labels=('ja','m','mhm','okay','achso','ah'))

# %%
label_timesteps
# Out:
# [('31-V-C-A.TextGrid',
#   {'ja': [(86.84232414529481, 86.95573536622493),
#     (120.77199999999999, 121.09199999999998),
#     (143.724, 143.86406379751085),
#     (169.32016718620324, 169.51748539698397),
#     (213.58596988393936, 213.7723796007122),
#     (241.91625965022362, 242.41768036354063),
#     (261.86582391251545, 262.0448013799475),
#     (279.02246700099187, 279.4487619628363)],
#    'm': [(69.96623653421857, 70.24926843511527),
#     (110.26775387122237, 110.5822337611076),
#     (130.3044941590972, 130.61161309535856),
#     (135.04399999999998, 135.32273954010887),
#     (145.05694897071024, 145.32163621136365),
#     (147.87740921097904, 148.23556686334834),
#     (162.4576389844746, 162.78172798210633),
#     (185.7578687579701, 186.06448665060822),
#     (194.14048942371915, 194.45060153735596),
#     (209.14799999999997, 209.4704635346031),
#     (217.5257307552172, 217.81552638917074),
#     (233.61199999999997, 233.9464635346031),
# ...

# %%
wav_file, sample_rate, _=extract_utterance_according_timesteps(path_to_file=r'E:\Databases\ALICO\ALICO\recordings\34-V-NC-B.wav', timesteps=(40.0, 50.0), additional_interval=0)

# %%
sample_rate
# Out:
# 48000

# %%
import IPython
def write_wav_file(path:str, data:np.ndarray, sample_rate:int)->None:
    wavfile.write(path, sample_rate, data)
write_wav_file(path='tmp_audio.wav', data=wav_file, sample_rate=sample_rate)

IPython.display.Audio('tmp_audio.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
